# %%
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerLine2D
#from pylab import rcParams
#rcParams['figure.figsize'] = 6,6.9

x=[0,1,2,3,4,5,6,7]

ivector=[19.1,18.7, 18.8, 18.7, 18.6, 18.6, 18.6, 18.7]
partitioned_dnn=[19.1,18.7, 18.4, 18.3, 18.4, 18.4, 18.3, 18.2]
#ivec_nonlinear_one=[19.1,18.5, 18.7, 18.9, 18.8, 18.7, 18.8, 18.8]
ivec_nonlinear_one=[19.1,18.7, 18.8, 18.7, 18.8, 18.7, 18.6, 18.5]
ivec_nonlinear_two=[19.1,18.8, 18.9, 18.9, 18.7, 18.7, 18.7, 18.6]
#ivec_nonlinear_two=[19.1,18.8, 18.6, 18.6, 18.7, 18.5, 18.5, 18.5]


plt.xlabel('# Layers with speaker input')
plt.xticks(x)

line1= plt.plot(x,partitioned_dnn,label="Partitioned DNN", marker='s',ms=9,ls='-',lw=2)
line2= plt.plot(x,ivector,label="Extended iVec",marker='o',ms=9,ls='-',lw=2)
line3= plt.plot(x,ivec_nonlinear_one,label="Extended iVec 1-layer",marker='d',ms=9,ls='-',lw=2)
line4= plt.plot(x,ivec_nonlinear_two,label="Extended iVec 2-layer",marker='^',ms=9,ls='-',lw=2)

#plt.legend(bbox_to_anchor=(1.05, 1.05), loc=2, borderaxespad=0.)
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,ncol=2, mode="expand", borderaxespad=0)
#plt.legend(loc='upper center')
plt.ylabel('Phone Error Rate %')
plt.ylim(18.15,19.15)
#plt.show()

plt.savefig("compare.png",box='tight',  format='png', dpi=1000)
